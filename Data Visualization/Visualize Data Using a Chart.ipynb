# %% [markdown]
# # Visualize Data Using a Chart

# %% [markdown]
# ***

# %% [markdown]
# ## Project Description

# %% [markdown]
# The goal of this assignment is to give you some experience with handling and deciding how to visualize some data and for you to get a feel for the various aspects of the visualization.
#
# This assignment will also help you to analyze other visualizations and assess their effectiveness.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
from numpy import count_nonzero, median, mean
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import random

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

import datetime
from datetime import datetime, timedelta

import scipy.stats
from collections import Counter

# %matplotlib inline
#sets the default autosave frequency in seconds
# %autosave 60 
sns.set_style('dark')
sns.set(font_scale=1.2)

plt.rc('axes', titlesize=9)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format','{:.2f}'.format)

random.seed(0)
np.random.seed(0)
np.set_printoptions(suppress=True)
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = pd.read_csv("Graph1.csv", index_col="Year")

# %%
df
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 2000   26   59   59   59   40   43   42   43   43   29   33   30
# 2001   45   47   58   52   59   54   60   50   56   52   71   55
# 2002   74   76   91   59   65   55   61   55   64   57   59   42
# 2003   72   55   57   55   63   48   55   66   67   75   55   74
# 2004   58   70   66   62   42   42   27   45   53   67   72   52
# 2005   72   59   69   70   64   66   66   63   77   80   75   68
# 2006   57   71   64   49   47   64   55   71   64   70   73   78
# 2007   97   70   70   75   69   59   62   61   65   61   57   49
# 2008   27   36   75   53   51   48   60   45   64   67   67   55
# 2009   62   54   53   61   64   67   73   68   69   65   78   65
# 2010   73   79   92   87   75   64   61   65   61   71   79   49
# 2011   50   51   64   66   53   59   74   73   56   67   56   53
# 2012   45   49   57   69   76   62   56   64   75   79   74   52
# ...

# %% [markdown]
# ## Time-Series Analysis

# %%
fig = plt.figure(figsize=(30,10))
sns.lineplot(x=df.index,y=df.Jan,data=df, estimator=None)
sns.lineplot(x=df.index,y=df.Feb,data=df, estimator=None)
sns.lineplot(x=df.index,y=df.Mar,data=df, estimator=None)
sns.lineplot(x=df.index,y=df.Apr,data=df, estimator=None)
sns.lineplot(x=df.index,y=df.May,data=df, estimator=None)
sns.lineplot(x=df.index,y=df.Jun,data=df, estimator=None)
plt.title("Global and Hemispheric Monthly Means", fontsize=20)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Temp", fontsize=20)
plt.legend(['Jan','Feb','Mar','Apr','May','Jun'])
plt.show()

# %% [markdown]
# #### Python code done by Dennis Lam
